# %% [markdown]
# # WoS EDA

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from pprint import pprint

# %%
#### LOAD DATA ####

with open('../input/data/train_dataset/train_dials.json', 'r') as f:
    train_dials = json.load(f)
    
with open('../input/data/train_dataset/slot_meta.json', 'r') as f:
    slot_meta = json.load(f)
    
with open('../input/data/train_dataset/ontology.json', 'r') as f:
    ontology = json.load(f)

# %%
#### DATAFRAME ###

# 1. id
# 2. conversation texts
# 3. domain
# 4. state

idx_lst = [] # 1
dia_lst = [] # 2
dom_lst = [] # 3
sta_lst = [] # 4

for idx in range(len(train_dials)):
    data = train_dials[idx] # current data
    # 1
    idx_lst.append(data['dialogue_idx'])
    # 2
    dialogue = ' '.join([s['text'] for s in data['dialogue']])
    dia_lst.append(dialogue)
    # 3 
    dom_lst.append(data['domains'])
    # 4
    for d in data['dialogue']:
        try:
            state = d['state']
        except:
            continue
    sta_lst.append(state)

data = {'id': idx_lst, 'conversation_texts': dia_lst, 'domain': dom_lst, 'state': sta_lst}

df = pd.DataFrame(data)

del idx_lst
del dia_lst
del dom_lst
del sta_lst
del data

display(df.head())
# Out:
#                                   id  \
# 0            snowy-hat-8324:관광_식당_11
# 1          polished-poetry-0057:관광_9
# 2  autumn-mountain-9993:식당_관광_지하철_14
# 3            calm-smoke-9954:관광_식당_7
# 4             falling-king-2544:택시_1
#
#                                   conversation_texts         domain  \
# 0  서울 중앙에 있는 박물관을 찾아주세요 안녕하세요. 문화역서울 284은 어떠신가요? ...       [관광, 식당]
# 1  쇼핑을 하려는데 서울 서쪽에 있을까요? 서울 서쪽에 쇼핑이 가능한 곳이라면 노량진 ...           [관광]
# 2  안녕하세요? 적당한 가격대의 양식당을 친구들이랑 방문하려고 하는데요. 어차피 지하철...  [식당, 관광, 지하철]
# 3  서울로 놀러왔는데 공원에 가고싶어서요. 어디로 가면 될까요? 안녕하세요. 어느 지역...       [관광, 식당]
# 4  요청할게 있습니다. 인사동에서 모텔 킹까지 가는 고급택시를 찾고있습니다.  안녕하세...           [택시]
#
#                                                state
# 0  [관광-종류-박물관, 관광-지역-서울 중앙, 관광-이름-문화역서울 284, 식당-가...
# 1        [관광-종류-쇼핑, 관광-지역-서울 서쪽, 관광-이름-노량진 수산물 도매시장]
# 2  [지하철-출발지-혜화역, 지하철-도착지-동대문역, 관광-종류-기타, 관광-지역-서울...
# 3  [관광-종류-공원, 관광-지역-dontcare, 관광-이름-서울로7017, 식당-가...
# 4  [택시-출발 시간-dontcare, 택시-출발지-인사동, 택시-도착지-모텔 킹, 택...

# %%
#### DOMAINS ####

domains = []
for lst in df['domain'].to_list():
    domains.extend(lst)
    
dom_val_cnt = Counter(domains)

print(dom_val_cnt)
# Out:
# Counter({'식당': 4020, '숙소': 3802, '관광': 3732, '택시': 2374, '지하철': 650})

# %%
#### SLOTS ####
# ex) {관광: ['종류', '종류', '지역', ...], ...}

def slots(x):
    slots_lst = [_.split('-') for _ in x['state']]
    slots_dct = dict()
    for lst in slots_lst:
        if lst[0] not in slots_dct:
            slots_dct[lst[0]] = [lst[1]]
        else:
            slots_dct[lst[0]].append(lst[1])
    return slots_dct

slots_processed = df.apply(lambda x: slots(x), axis=1)

slots_merged = dict()

for row in slots_processed:
    for key, val in row.items():
        if key not in slots_merged:
            slots_merged[key] = [_ for _ in val]
        else:
            slots_merged[key].extend(val)
            
for key in dom_val_cnt.keys():
    print(key)
    print(Counter(slots_merged[key]))
    print()
# Out:
# 관광
# Counter({'이름': 3575, '지역': 3081, '종류': 3079, '역사적': 704, '경치 좋은': 347, '주차 가능': 323, '교육적': 172, '문화 예술': 166, '도보 가능': 29})
#
# 식당
# Counter({'이름': 4002, '예약 요일': 3830, '예약 시간': 3829, '예약 명수': 3827, '가격대': 3380, '지역': 3377, '종류': 3377, '야외석 유무': 513, '주류 판매': 435, '주차 가능': 338, '흡연 가능': 319, '인터넷 가능': 173, '도보 가능': 57})
#
# 지하철
# Counter({'출발지': 649, '도착지': 649, '출발 시간': 121})
#
# 택시
# Counter({'출발 시간': 2374, '도착지': 2374, '종류': 2374, '출발지': 2373, '도착 시간': 1063})
#
# 숙소
# Counter({'이름': 3785, '예약 명수': 3674, '예약 요일': 3673, '예약 기간': 3673, '가격대': 3405, '종류': 3404, '지역': 3403, '스파 유무': 477, '주차 가능': 461, '인터넷 가능': 409, '흡연 가능': 375, '헬스장 유무': 317, '조식 가능': 307, '도보 가능': 138, '수영장 유무': 77})

# %%
#### VALUES ####

for key in ontology.keys():
    print(f'{key}: {ontology[key][:10]} ... ')
# Out:
# 관광-경치 좋은: ['none', 'dontcare', 'yes', 'no'] ...
# 관광-교육적: ['none', 'dontcare', 'no', 'yes'] ...
# 관광-도보 가능: ['none', 'dontcare', 'no', 'yes'] ...
# 관광-문화 예술: ['none', 'dontcare', 'no', 'yes'] ...
# 관광-역사적: ['none', 'dontcare', 'no', 'yes'] ...
# 관광-이름: ['none', 'dontcare', '북한산 국립공원', '한국 전쟁 기념관', '명동난타극장', '국립중앙박물관', '그레뱅뮤지엄', '경복궁', '창덕궁', '여의도 한강공원'] ...
# 관광-종류: ['none', 'dontcare', '공원', '박물관', '공연', '즐길거리', '랜드마크', '쇼핑', '여행자 자료', '기타'] ...
# 관광-주차 가능: ['none', 'dontcare', 'no', 'yes'] ...
# 관광-지역: ['none', 'dontcare', '서울 북쪽', '서울 중앙', '서울 동쪽', '서울 서쪽', '서울 남쪽'] ...
# 숙소-가격대: ['none', 'dontcare', '저렴', '비싼', '적당'] ...
# 숙소-도보 가능: ['none', 'dontcare', 'yes', 'no'] ...
# 숙소-수영장 유무: ['none', 'dontcare', 'no', 'yes'] ...
# 숙소-스파 유무: ['none', 'dontcare', 'no', 'yes'] ...
# 숙소-예약 기간: ['none', 'dontcare', '3', '1', '5', '2', '6', '4', '10', '9'] ...
# 숙소-예약 명수: ['none', 'dontcare', '1', '2', '6', '5', '4', '3', '8', '7'] ...
# 숙소-예약 요일: ['none', 'dontcare', '수요일', '일요일', '금요일', '월요일', '토요일', '목요일', '화요일'] ...
# 숙소-이름: ['none', 'dontcare', '동키 게스트 하우스', '마라톤 서울 호텔', '프리미어 호텔', '호스텔 제이제이', '프린스 호텔 서울', '고구려 호스텔', '서촌 한옥 게스트하우스', '서운정'] ...
# 숙소-인터넷 가능: ['none', 'dontcare', 'yes', 'no'] ...
# 숙소-조식 가능: ['none', 'dontcare', 'yes', 'no'] ...
# 숙소-종류: ['none', 'dontcare', '게스트 하우스', '호텔', '호스텔', '에어비엔비', '모텔'] ...
# 숙소-주차 가능: ['none', 'dontcare', 'no', 'yes'] ...
# 숙소-지역: ['none', 'dontcare', '서울 중앙', '서울 서쪽', '서울 동쪽', '서울 남쪽', '서울 북쪽'] ...
# 숙소-헬스장 유무: ['none', 'dontcare', 'no', 'yes'] ...
# 숙소-흡연 가능: ['none', 'dontcare', 'no', 'yes'] ...
# 식당-가격대: ['none', 'dontcare', '저렴', '비싼', '적당'] ...
# 식당-도보 가능: ['none', 'dontcare', 'yes', 'no'] ...
# 식당-야외석 유무: ['none', 'dontcare', 'no', 'yes'] ...
# 식당-예약 명수: ['none', 'dontcare', '1', '4', '3', '9', '8', '2', '6', '5'] ...
# 식당-예약 시간: ['none', 'dontcare', '18:00', '03:30', '12:30', '02:20', '17:30', '19:30', '17:00', '16:10'] ...
# 식당-예약 요일: ['none', 'dontcare', '토요일', '금요일', '수요일', '월요일', '목요일', '화요일', '일요일'] ...
# 식당-이름: ['none', 'dontcare', '뽀식이네 감자탕', '내맘속의나폴리', '꼬끼오꼬꼬', '믿고맡기는초밥', '오동통규동동', '친구를 만나느라 샵샵샵', '외계인의맛집', '한국인의김치상'] ...
# 식당-인터넷 가능: ['none', 'dontcare', 'no', 'yes'] ...
# 식당-종류: ['none', 'dontcare', '한식당', '양식당', '일식당', '베이커리', '분식집', '치킨집', '중식당', '주점'] ...
# 식당-주류 판매: ['none', 'dontcare', 'yes', 'no'] ...
# 식당-주차 가능: ['none', 'dontcare', 'yes', 'no'] ...
# 식당-지역: ['none', 'dontcare', '서울 중앙', '서울 북쪽', '서울 남쪽', '서울 동쪽', '서울 서쪽'] ...
# 식당-흡연 가능: ['none', 'dontcare', 'no', 'yes'] ...
# 지하철-도착지: ['none', 'dontcare', '용산역', '삼각지역', '을지로입구역', '월드컵경기장역', '광화문역', '신촌역', '시청역', '홍대입구역'] ...
# 지하철-출발 시간: ['none', 'dontcare', '13:30', '13:10', '12:40', '12:30', '12:00', '12:20', '12:50', '13:40'] ...
# 지하철-출발지: ['none', 'dontcare', '왕십리역', '용산역', '삼각지역', '을지로입구역', '월드컵경기장역', '광화문역', '신촌역', '시청역'] ...
# 택시-도착 시간: ['none', 'dontcare', '13:20', '04:50', '21:45', '21:30', '18:00', '10:45', '15:00', '10:00'] ...
# 택시-도착지: ['none', 'dontcare', '모텔 킹', '서울 역사 박물관', '회오리라멘', '포레스트 호텔', '패밀리 호텔', '노원역', '꼬끼오꼬꼬', '혜화역'] ...
# 택시-종류: ['none', 'dontcare', '고급', '에코', '개인'] ...
# 택시-출발 시간: ['none', 'dontcare', '12:45', '10:00', '13:00', '03:00', '04:30', '20:30', '08:45', '13:50'] ...
# 택시-출발지: ['none', 'dontcare', '인사동', '엄중식', '야드 서울', '분식회개', '잠실역', '왕십리역', '종각역', '서울중앙성원'] ...

# %%
#### N-GRAMS PER DOMAIN ####

def ngrams_dcts(dials, N):
    gram_dct = {k: [] for k in dom_val_cnt.keys()}
    for idx in range(len(dials)):
        prev_state = []
        for s in dials[idx]['dialogue']:
            if s['role'] != 'user':
                continue
            cur_state = s['state']
            added_state = list(set(cur_state) - set(prev_state))
            if len(added_state) != 0:
                domains = list(set([_.split('-')[0] for _ in added_state]))
                for cur_dom in domains:
                    words = s['text'].split(' ')
                    if len(words) < N:
                        continue
                    for idx_ in range(len(words)):
                        if idx_ == len(words) - N + 1:
                            break
                        next_gram = tuple([_ for _ in words[idx_: idx_ + N]])
                        gram_dct[cur_dom].append(next_gram)
            prev_state = cur_state
    return gram_dct

# %%
#### BIGRAM ####
#### QUERIES ONLY #####

print('==============BIGRAM===============', '\n')
bigram_dct = ngrams_dcts(train_dials, 2)
TOP_N = 10
for dom in dom_val_cnt.keys():
    print(f'============ {dom} TOP{TOP_N} ============')
    pprint(Counter(bigram_dct[dom]).most_common(TOP_N))
    print()
# Out:
# ==============BIGRAM===============
#
# ============ 관광 TOP10 ============
# [(('어떻게', '되나요?'), 489),
#  (('서울', '북쪽에'), 414),
#  (('서울', '중앙에'), 412),
#  (('안녕하세요.', '서울'), 290),
#  (('경치가', '좋은'), 270),
#  (('그리고', '서울'), 260),
#  (('좀', '알려주세요.'), 239),
#  (('수', '있나요?'), 216),
#  (('같은', '지역에'), 206),
#  (('관광지를', '찾고'), 193)]
#
# ============ 식당 TOP10 ============
# [(('적당한', '가격대의'), 454),
#  (('서울', '중앙에'), 413),
#  (('안녕하세요.', '서울'), 350),
#  (('서울', '남쪽에'), 295),
#  (('서울', '북쪽에'), 289),
#  (('서울', '서쪽에'), 265),
#  (('서울', '동쪽에'), 251),
#  (('예약', '좀'), 238),
#  (('같은', '지역에'), 236),
#  (('예약해', '주세요.'), 229)]
#
# ============ 지하철 TOP10 ============
# [(('가는', '지하철을'), 97),
#  (('가는', '지하철'), 62),
#  (('어떻게', '되나요?'), 52),
#  (('근처', '역에서'), 48),
#  (('식당', '근처'), 43),
#  (('노선이', '어떻게'), 38),
#  (('역으로', '가는'), 37),
#  (('가는', '지하철도'), 36),
#  (('관광지', '근처'), 35),
#  (('지하철', '타고'), 30)]
#
# ============ 택시 TOP10 ============
# [(('택시', '종류는'), 279),
#  (('가는', '택시를'), 258),
#  (('가는', '택시도'), 228),
#  (('출발', '시간은'), 225),
#  (('종류는', '아무거나'), 194),
#  (('택시', '좀'), 174),
#  (('저', '그리고'), 155),
#  (('좀', '알려주세요.'), 136),
#  (('수', '있는'), 133),
#  (('아무거나', '괜찮아요.'), 119)]
#
# ============ 숙소 TOP10 ============
# [(('적당한', '가격대의'), 432),
#  (('안녕하세요.', '서울'), 364),
#  (('서울', '남쪽에'), 326),
#  (('서울', '동쪽에'), 316),
#  (('서울', '중앙에'), 314),
#  (('서울', '서쪽에'), 304),
#  (('서울', '북쪽에'), 284),
#  (('숙소를', '찾고'), 266),
#  (('예약', '좀'), 213),
#  (('예약해', '주세요.'), 212)]

# %%
#### TRIGRAM ####
#### QUERIES ONLY #####

print('==============TRIGRAM==============', '\n')
trigram_dct = ngrams_dcts(train_dials, 3)
TOP_N = 10
for dom in dom_val_cnt.keys():
    print(f'============ {dom} TOP{TOP_N} ============')
    pprint(Counter(trigram_dct[dom]).most_common(TOP_N))
    print()
# Out:
# ==============TRIGRAM==============
#
# ============ 관광 TOP10 ============
# [(('서울', '중앙에', '있는'), 167),
#  (('서울', '북쪽에', '있는'), 135),
#  (('알', '수', '있을까요?'), 122),
#  (('같은', '지역에', '있는'), 84),
#  (('영업', '시간이', '어떻게'), 80),
#  (('그리고', '서울', '중앙에'), 76),
#  (('서울', '남쪽에', '있는'), 74),
#  (('영업', '시간', '좀'), 71),
#  (('저', '그리고', '서울'), 67),
#  (('안녕하세요.', '서울', '북쪽에'), 66)]
#
# ============ 식당 TOP10 ============
# [(('서울', '중앙에', '있는'), 162),
#  (('같은', '지역에', '있는'), 132),
#  (('서울', '남쪽에', '있는'), 98),
#  (('서울', '북쪽에', '있는'), 95),
#  (('안녕하세요.', '서울', '중앙에'), 92),
#  (('있는', '적당한', '가격대의'), 91),
#  (('서울', '동쪽에', '있는'), 89),
#  (('예약', '좀', '해주세요.'), 79),
#  (('예약', '해', '주세요.'), 74),
#  (('서울', '서쪽에', '있는'), 72)]
#
# ============ 지하철 TOP10 ============
# [(('근처', '역으로', '가는'), 27),
#  (('노선이', '어떻게', '되나요?'), 21),
#  (('식당', '근처', '역에서'), 19),
#  (('지하철', '노선이', '어떻게'), 18),
#  (('감사합니다.', '저', '그리고'), 17),
#  (('관광지', '근처', '역에서'), 15),
#  (('라인이', '어떻게', '되나요?'), 14),
#  (('역으로', '가는', '지하철의'), 14),
#  (('근처', '역에서', '숙소'), 12),
#  (('도착지', '라인이', '어떻게'), 12)]
#
# ============ 택시 TOP10 ============
# [(('택시', '종류는', '아무거나'), 92),
#  (('감사합니다.', '저', '그리고'), 71),
#  (('갈', '수', '있는'), 70),
#  (('저', '그리고', '택시를'), 69),
#  (('종류는', '아무거나', '괜찮아요.'), 59),
#  (('다른', '건', '다'), 54),
#  (('예약', '해', '주세요.'), 51),
#  (('가는', '택시', '좀'), 48),
#  (('택시도', '예약해', '주세요.'), 47),
#  (('택시를', '예약하고', '싶은데요.'), 46)]
#
# ============ 숙소 TOP10 ============
# [(('서울', '중앙에', '있는'), 103),
#  (('서울', '남쪽에', '있는'), 94),
#  (('예약', '해', '주세요.'), 89),
#  (('서울', '동쪽에', '있는'), 85),
#  (('서울', '북쪽에', '있는'), 79),
#  (('서울', '서쪽에', '있는'), 78),
#  (('같은', '지역에', '있는'), 76),
#  (('숙소를', '찾고', '있어요.'), 75),
#  (('안녕하세요.', '서울', '남쪽에'), 73),
#  (('있는', '적당한', '가격대의'), 73)]
